# %%
if __name__ == "__main__":
    year = getMakesByYear()
    make = getCarModelsByMake(year)
    model = modelSelect()
    engineData = getEngineByModel(year, make, model)
    engine = int(engineSelect())
    
    print(make, model, engine)
#     search = search_options(year)
#     print(search)
#     print(search)
# Out:
# Please enter the year of the car you wish to find:
# Here is a list of manufacturers that released cars in the year: 2020
# Acura
# Alfa Romeo
# Aston Martin
# Audi
# Bentley
# BMW
# Buick
# Cadillac
# Chevrolet
# Chrysler
# Dodge
# FIAT
# Ford
# Genesis
# GMC
# Honda
# Hyundai
# INFINITI
# Jaguar
# Jeep
# Kia
# Lamborghini
# Land Rover
# Lexus
# Lincoln
# Lotus
# Maserati
# Mazda
# McLaren
# Mercedes-Benz
# MINI
# Mitsubishi
# Nissan
# Polestar
# Porsche
# Ram
# Rolls-Royce
# Subaru
# Tesla
# Toyota
# Volkswagen
# Volvo
# Please enter the make you wish to find:
# You selected: Volvo
# Volvo, Model: S60
# Volvo, Model: S90
# Volvo, Model: V60
# Volvo, Model: V60 Cross Country
# Volvo, Model: V90
# Volvo, Model: V90 Cross Country
# Volvo, Model: XC40
# Volvo, Model: XC60
# Volvo, Model: XC90
# Please select a model from the list for more details:
# You selected: XC90
# [1, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [2, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [3, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [4, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [5, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [6, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [8, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [10, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [16, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [18, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [7, 'gas', '5.0', 316, 'all wheel drive']
# [9, 'gas', '5.0', 316, 'all wheel drive']
# [11, 'gas', '5.0', 250, 'all wheel drive']
# [12, 'gas', '5.0', 250, 'front wheel drive']
# [13, 'gas', '5.0', 250, 'all wheel drive']
# [14, 'gas', '5.0', 316, 'all wheel drive']
# [15, 'gas', '5.0', 316, 'all wheel drive']
# [17, 'gas', '5.0', 250, 'front wheel drive']
# [19, 'gas', '5.0', 316, 'all wheel drive']
# Please select an engine from the list for more details:
# You selected: 2
# Volvo XC90 2

# %%
import requests
import json
import pandas as pd

# API
# https://carapi.app/api#/Models/makemodels%3Aindex%3Aget
url = "https://www.carqueryapi.com/api/0.3/"
makes = "https://car-api2.p.rapidapi.com/api/makes"
years = "https://car-api2.p.rapidapi.com/api/years"
models = "https://car-api2.p.rapidapi.com/api/models"
engines = "https://car-api2.p.rapidapi.com/api/engines"

headers = {
    "X-RapidAPI-Key": "a128349cd3msha07615f87e1be36p146ca1jsn2b1dce4fe9d3",
    "X-RapidAPI-Host": "car-api2.p.rapidapi.com"
}

# %%
def getMakesByYear():
    year = input("Please enter the year of the car you wish to find: ") or "2020"
    params = {
        "year": year
    }
    
    response = requests.request("GET", makes, headers=headers, params=params)
    #Response 200, successful query
    car_data = response.json()
    car_data = car_data["data"]
    
    print(f"Here is a list of manufacturers that released cars in the year: {year}")
    
    for manufacturer in car_data:
        print(manufacturer["name"])
    return year

# %%
def getCarModelsByMake(year):
    make = input("Please enter the make you wish to find: ") or "Volvo"
    print(f"You selected: {make}")
    params = {
        "year": year,
        "make": make
    }
    response = requests.request("GET", models, headers=headers, params=params)
    #Response 200, successful query
    car_data = response.json()
    data = car_data["data"]
    try:
        for item in data:
            print(f"{make}, Model: " + item["name"])
    except TypeError:
        pass
    return make
#     for item in data:
#         print(f"{make}, Model: " + item["name"]) 
        
#     try:
#         for item in model:
#                 print(item)
#     except TypeError:
#         pass
# getCarModelsByMake("Audi")

# %%
def getEngineByModel(year, make, model):
    params = {
        "year": year,
        "verbose": "yes",
        "make": make,
        "model": model
    }
    count = 0
    gasPower = []
    response = requests.request("GET", engines, headers=headers, params=params)
    car_data = response.json()
    for item in car_data["data"]:
        count += 1
        data = [count, item["engine_type"], item["size"], item["horsepower_hp"], item["drive_type"]]
        if data[1] == "gas":
            gasPower.append(data)
        else:
            print(data)
    for item in gasPower:
        print(item)

# %%
def modelSelect():
    model_select = input("Please select a model from the list for more details: ") or "XC90"
    print(f"You selected: {model_select}")
    model = model_select
    return model

# %%
def engineSelect():
    engine_select = input("Please select an engine from the list for more details: ") or "2"
    print(f"You selected: {engine_select}")
    engine = engine_select
    return engine

# %%
def searchOptions(year):
    search = {}
    for i in range(1):
        make1 = input("Make: ") or "BMW"
        model1 = input("Model: ") or "M4"
        engine1 = input("Engine: ") or "5.0"
        search = (year, make1, model1, engine1)
    return search

# %%
def getEngineByCar(model, search):
    params = {
        "year": "2020",
        "verbose": "yes",
        "make": "Audi",
        "model": model
    }
    response = requests.request("GET", engines, headers=headers, params=params)
    car_data = response.json()
    print(model)
    print("| Engine type | Engine Size | Horsepower |")
#     print(car_data["data"])
#     for item in car_data:
#         print(item["description"])
#     for item in car_data["data"]:
#         print("| ", item["engine_type"], " | " , item["size"], " | " , item["horsepower_hp"], " | " , item["drive_type"], " | ")

# getEngineByCar("A3")

# %%
def getEngineByModel(year, make, model):
    params = {
        "year": year,
        "verbose": "yes",
        "make": make,
        "model": model
    }
    count = 0
    response = requests.request("GET", engines, headers=headers, params=params)
    car_data = response.json()
    for item in car_data["data"]:
        count += 1
        data = [count, item["engine_type"], item["size"], item["horsepower_hp"], item["drive_type"]]
        print(data)
#         return data
#         car_info = {
#             "info": [
#                 {"engine_type": item["engine_type"],
#                  "engine_size": item["size"],
#                  "horse_power": item["horsepower_hp"]}
#             ]
#         }
#     df = pd.DataFrame(car_info["info"])
#     df = df[["engine_type", "engine_size", "horse_power"]]
#     print(df)
#     print(df, "\n")
    
# getEngineByModel("MDX")

# %%
getEngineByModel(year, make, model)

# for item in getEngineByModel(year, make, model):
#     print(item)
# Out:
# [1, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [2, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [3, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [4, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [5, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [6, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [7, 'gas', '5.0', 316, 'all wheel drive']
# [8, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [9, 'gas', '5.0', 316, 'all wheel drive']
# [10, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [11, 'gas', '5.0', 250, 'all wheel drive']
# [12, 'gas', '5.0', 250, 'front wheel drive']
# [13, 'gas', '5.0', 250, 'all wheel drive']
# [14, 'gas', '5.0', 316, 'all wheel drive']
# [15, 'gas', '5.0', 316, 'all wheel drive']
# [16, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [17, 'gas', '5.0', 250, 'front wheel drive']
# [18, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [19, 'gas', '5.0', 316, 'all wheel drive']

# %%
def engineSelect():
    engine_select = input("Please select an engine from the list for more details: ") or "2"
    print(f"You selected: {engine_select}")
    engineList = getEngineByModel("2020", "Volvo", "XC90")
    for engine in engineList():
        print(engine)
    return engine

engineSelect()
# Out:
# Please select an engine from the list for more details:
# You selected: 2
# [1, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [2, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [3, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [4, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [5, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [6, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [7, 'gas', '5.0', 316, 'all wheel drive']
# [8, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [9, 'gas', '5.0', 316, 'all wheel drive']
# [10, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [11, 'gas', '5.0', 250, 'all wheel drive']
# [12, 'gas', '5.0', 250, 'front wheel drive']
# [13, 'gas', '5.0', 250, 'all wheel drive']
# [14, 'gas', '5.0', 316, 'all wheel drive']
# [15, 'gas', '5.0', 316, 'all wheel drive']
# [16, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [17, 'gas', '5.0', 250, 'front wheel drive']
# [18, 'plug-in hybrid', '5.0', 400, 'all wheel drive']
# [19, 'gas', '5.0', 316, 'all wheel drive']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 9
#       6         print(engine)
#       7     return engine
# ----> 9 engineSelect()
#
# Cell In[81], line 5, in engineSelect()
#       3 print(f"You selected: {engine_select}")
#       4 engineList = getEngineByModel("2020", "Volvo", "XC90")
# ----> 5 for engine in engineList():
#       6     print(engine)
#       7 return engine
#
# TypeError: 'NoneType' object is not callable
